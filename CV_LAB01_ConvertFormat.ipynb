# %% [markdown]
# Using cv2

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %% [markdown]
# Using imageio and format conversion

# %%
import imageio as iio
img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
iio.imwrite("test.png", img)
# Out:
# <ipython-input-13-c8f2dca726d5>:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")

# %% [markdown]
# Using matplotlib

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('test.png')
plt.imshow(img)

# %% [markdown]
# Using PIL

# %%
from PIL import Image
img=Image.open('/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg')
img.show()

# %% [markdown]
# Format conversion

# %%
img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
iio.imwrite("test.jpg", img)
# Out:
# <ipython-input-21-ff643901cc54>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")

# %%
img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
iio.imwrite("test.jpe", img)
# Out:
# <ipython-input-22-4c32da23bf00>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")

# %%
img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
iio.imwrite("test.tiff", img)
# Out:
# <ipython-input-23-a24e55064f47>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/depositphotos_31129547-stock-photo-venice-landmark-burano-island-canal.jpg")
